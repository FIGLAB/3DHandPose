# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
depth = np.load("./data/1591741774_depth.npy")
ir = np.load("./data/1591741774_ir.npy")

# %%
plt.subplots(1,1, figsize=(10,10))
plt.imshow(np.clip(depth, 700, 900))
plt.colorbar()

# %%
plt.imshow(ir)
